# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('sentimentdataset.csv')

# %%
data.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
# 1             1           1
# 2             2           2
# 3             3           3
# 4             4           4
#
#                                                 Text    Sentiment  \
# 0   Enjoying a beautiful day at the park!        ...   Positive
# 1   Traffic was terrible this morning.           ...   Negative
# 2   Just finished an amazing workout! 💪          ...   Positive
# 3   Excited about the upcoming weekend getaway!  ...   Positive
# 4   Trying out a new recipe for dinner tonight.  ...   Neutral
#
#              Timestamp            User     Platform  \
# 0  2023-01-15 12:30:00   User123          Twitter
# 1  2023-01-15 08:45:00   CommuterX        Twitter
# 2  2023-01-15 15:45:00   FitnessFan      Instagram
# 3  2023-01-15 18:20:00   AdventureX       Facebook
# 4  2023-01-15 19:55:00   ChefCook        Instagram
#
#                                      Hashtags  Retweets  Likes       Country  \
# ...

# %%
data.tail()
# Out:
#      Unnamed: 0.1  Unnamed: 0  \
# 727           728         732
# 728           729         733
# 729           730         734
# 730           731         735
# 731           732         736
#
#                                                   Text Sentiment  \
# 727  Collaborating on a science project that receiv...    Happy
# 728  Attending a surprise birthday party organized ...    Happy
# 729  Successfully fundraising for a school charity ...    Happy
# 730  Participating in a multicultural festival, cel...    Happy
# 731  Organizing a virtual talent show during challe...    Happy
#
#                Timestamp                                   User     Platform  \
# 727  2017-08-18 18:20:00       ScienceProjectSuccessHighSchool     Facebook
# 728  2018-06-22 14:15:00            BirthdayPartyJoyHighSchool    Instagram
# 729  2019-04-05 17:30:00   CharityFundraisingTriumphHighSchool      Twitter
# 730  2020-02-29 20:45:00    MulticulturalFestivalJoyHighSchool     Facebook
# ...

# %%
data.shape
# Out:
# (732, 15)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 732 entries, 0 to 731
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0.1  732 non-null    int64
#  1   Unnamed: 0    732 non-null    int64
#  2   Text          732 non-null    object
#  3   Sentiment     732 non-null    object
#  4   Timestamp     732 non-null    object
#  5   User          732 non-null    object
#  6   Platform      732 non-null    object
#  7   Hashtags      732 non-null    object
#  8   Retweets      732 non-null    float64
#  9   Likes         732 non-null    float64
#  10  Country       732 non-null    object
#  11  Year          732 non-null    int64
#  12  Month         732 non-null    int64
#  13  Day           732 non-null    int64
#  14  Hour          732 non-null    int64
# dtypes: float64(2), int64(6), object(7)
# memory usage: 85.9+ KB

# %%
data.isnull().sum()
# Out:
# Unnamed: 0.1    0
# Unnamed: 0      0
# Text            0
# Sentiment       0
# Timestamp       0
# User            0
# Platform        0
# Hashtags        0
# Retweets        0
# Likes           0
# Country         0
# Year            0
# Month           0
# Day             0
# Hour            0
# dtype: int64

# %%
data.describe()
# Out:
#        Unnamed: 0.1  Unnamed: 0    Retweets       Likes         Year  \
# count    732.000000  732.000000  732.000000  732.000000   732.000000
# mean     366.464481  369.740437   21.508197   42.901639  2020.471311
# std      211.513936  212.428936    7.061286   14.089848     2.802285
# min        0.000000    0.000000    5.000000   10.000000  2010.000000
# 25%      183.750000  185.750000   17.750000   34.750000  2019.000000
# 50%      366.500000  370.500000   22.000000   43.000000  2021.000000
# 75%      549.250000  553.250000   25.000000   50.000000  2023.000000
# max      732.000000  736.000000   40.000000   80.000000  2023.000000
#
#             Month         Day        Hour
# count  732.000000  732.000000  732.000000
# mean     6.122951   15.497268   15.521858
# std      3.411763    8.474553    4.113414
# min      1.000000    1.000000    0.000000
# 25%      3.000000    9.000000   13.000000
# 50%      6.000000   15.000000   16.000000
# 75%      9.000000   22.000000   19.000000
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'Text', 'Sentiment', 'Timestamp', 'User',
#        'Platform', 'Hashtags', 'Retweets', 'Likes', 'Country', 'Year', 'Month',
#        'Day', 'Hour', 'text_length'],
#       dtype='object')

# %%
plt.figure(figsize=(8,6))
data.head(30)['Sentiment'].value_counts().plot(kind='bar')
plt.title('Distribution of sentiment labels')
plt.xlabel('sentiment')
plt.ylabel('count')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# In the above graph it shows high positive sentiment in distribution of sentiment label.

# %%
data['word_count'] = data['Text'].apply(lambda x: len(str(x).split()))
data['word_count'].head(20).plot(kind='hist', bins=20, color='lightgreen', figsize=(6,4))
plt.title('Distribution of Word Count in Posts')
plt.xlabel('Word Count')
plt.ylabel('Frequency')
plt.show()`

# %% [markdown]
# The histogram of word count in posts reveals the frequency distribution, indicating whether most posts are short, medium, or long in length, which can inform the overall engagement and style of the content

# %%
platform_user_count = data.groupby('Platform')['User'].nunique().sort_values()
plt.figure(figsize=(10, 6))
platform_user_count.plot(kind='bar', color='skyblue')
plt.title('Number of Unique Users by Platform')
plt.xlabel('Platform')
plt.ylabel('Number of Unique Users')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# highest number of unique user is on instagram platform.

# %%
data['Sentiment'].head(20).value_counts().plot(kind='pie', autopct='%1.1f%%', startangle=90, figsize=(6, 6), colors=['lightgreen', 'salmon', 'gold'])
plt.title('Proportion of Sentiments')
plt.ylabel('')
plt.show()

# %%
data['Hashtags'].head(10).value_counts().plot(kind='pie', autopct='%1.1f%%', startangle=90, figsize=(6, 6), colors=['lightgreen', 'salmon', 'gold'])
plt.title('Proportion of Hashtags')
plt.ylabel('')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.scatter(data.head(30)['Year'],data.head(30)['Likes'])
plt.title('years per likes')
plt.xlabel('year')
plt.ylabel('likes')
plt.show()

# %% [markdown]
# In the above graph 2002 to 2025 having more likes.

# %%
plt.figure(figsize=(10,7))
platform_country_count = data.head(30).groupby(['Country', 'Platform']).size().unstack()
platform_country_count.plot(kind='bar', stacked=True, figsize=(10,6), color=['purple', 'orange', 'green', 'blue'])
plt.title('Platform Usage by Country')
plt.xlabel('Country')
plt.ylabel('Platform Count')
plt.xticks(rotation=45)
plt.legend(title='Platform', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
#Sentiment vs. Length of Posts:
# Calculate the length of each post (word count)
data['text_length'] = data['Text'].apply(lambda x: len(str(x).split()))
# Create a boxplot to compare text length across different sentiments
data.head(10).boxplot(column='text_length', by='Sentiment', grid=False, figsize=(10,6))
# Set plot labels and title
plt.title('Sentiment vs. Length of Posts')
plt.suptitle('')  # Remove default title
plt.xlabel('Sentiment')
plt.ylabel('Text Length (Word Count)')
plt.show()
