# %% [markdown]
# Importing Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import pandas as pd
# ----> 2 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'

# %% [markdown]
# Loading and reading dataset

# %%
# Load the dataset
df = pd.read_csv('house_cleaned.csv')
df.head()
# Out:
#                                       property_name property_type  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon         house
# 1  5 Bedroom House for sale in Sector 21A Faridabad         house
# 2  10 Bedroom House for sale in Sushant Lok Phase 1         house
# 3    21 Bedroom House for sale in Sector 54 Gurgaon         house
# 4  12 Bedroom House for sale in Sushant Lok Phase 1         house
#
#             society  price  price_per_sqft    area  \
# 0  bptp visionnaire   5.25         20115.0  2610.0
# 1       independent   5.70        105751.0   539.0
# 2       independent   2.10         38251.0   549.0
# 3       independent   5.00         43066.0  1161.0
# 4       independent   3.00         53763.0   558.0
#
#                   areaWithType  bedRoom  bathroom balcony  \
# 0  Plot area 290(242.48 sq.m.)        5         4      3+
# 1   Plot area 539(50.07 sq.m.)        5         4       2
# 2       Plot area 61(51 sq.m.)       10        10      3+
# ...

# %%
df.tail()
# Out:
#                                      property_name property_type  \
# 959  4 Bedroom House for sale in Sector 26 Gurgaon         house
# 960        3 Bedroom House for sale in DLF Phase 2         house
# 961  3 Bedroom House for sale in Sector 26 Gurgaon         house
# 962  3 Bedroom House for sale in Sector 26 Gurgaon         house
# 963             3 Bedroom House for sale in Bissar         house
#
#                                       society  price  price_per_sqft    area  \
# 959                          dlf city phase 1   5.50         30556.0  1800.0
# 960                    dlf city plots phase 2   4.25         31481.0  1350.0
# 961                          dlf city phase 1   4.50         33333.0  1350.0
# 962                          dlf city phase 1   3.25         33129.0   981.0
# 963  silverglades tarudhan valley golf resort   3.60         14815.0  2430.0
#
#                     areaWithType  bedRoom  bathroom balcony  \
# ...

# %%
df.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.shape
#
# NameError: name 'df' is not defined

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 964 entries, 0 to 963
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    964 non-null    object
#  1   property_type    964 non-null    object
#  2   society          964 non-null    object
#  3   price            945 non-null    float64
#  4   price_per_sqft   945 non-null    float64
#  5   area             945 non-null    float64
#  6   areaWithType     964 non-null    object
#  7   bedRoom          964 non-null    int64
#  8   bathroom         964 non-null    int64
#  9   balcony          964 non-null    object
#  10  additionalRoom   964 non-null    object
#  11  address          959 non-null    object
#  12  floorNum         945 non-null    float64
#  13  facing           661 non-null    object
#  14  agePossession    964 non-null    object
#  15  nearbyLocations  848 non-null    object
# ...

# %% [markdown]
# Data preprocessing

# %%
# Get summary statistics
df.describe()
# Out:
#             price  price_per_sqft          area     bedRoom    bathroom  \
# count  945.000000    9.450000e+02  9.450000e+02  964.000000  964.000000
# mean     4.911069    2.825156e-03  1.055610e+04    5.117220    4.825726
# std      4.651008    4.284827e-03  2.359139e+05    3.253843    3.350535
# min      0.070000    2.000000e-07  4.500000e+01    1.000000    1.000000
# 25%      1.200000    1.008547e-03  9.500000e+02    3.000000    3.000000
# 50%      3.600000    1.923077e-03  1.809000e+03    4.000000    4.000000
# 75%      7.000000    3.024691e-03  3.191000e+03    6.000000    6.000000
# max     31.500000    6.000000e-02  7.250000e+06   36.000000   36.000000
#
#          floorNum
# count  945.000000
# mean     2.759788
# std      2.923544
# min      0.000000
# 25%      2.000000
# 50%      2.000000
# 75%      3.000000
# max     51.000000

# %% [markdown]
# Data cleaning

# %%
print(df.isnull().sum())
# Out:
# property_name        0
# property_type        0
# society              0
# price               19
# price_per_sqft      19
# area                19
# areaWithType         0
# bedRoom              0
# bathroom             0
# balcony              0
# additionalRoom       0
# address              5
# floorNum            19
# facing             303
# agePossession        0
# nearbyLocations    116
# description          0
# furnishDetails     235
# features           302
# rating             121
# dtype: int64

# %%
df_cleaned = df.dropna()
print( df.shape)
print(df_cleaned.shape)
df_cleaned.head()
# Out:
# (964, 20)
# (406, 20)
#                                       property_name property_type  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon         house
# 2  10 Bedroom House for sale in Sushant Lok Phase 1         house
# 3    21 Bedroom House for sale in Sector 54 Gurgaon         house
# 4  12 Bedroom House for sale in Sushant Lok Phase 1         house
# 5  20 Bedroom House for sale in Sushant Lok Phase 1         house
#
#             society  price  price_per_sqft    area  \
# 0  bptp visionnaire   5.25         20115.0  2610.0
# 2       independent   2.10         38251.0   549.0
# 3       independent   5.00         43066.0  1161.0
# 4       independent   3.00         53763.0   558.0
# 5       independent   4.50         39062.0  1152.0
#
#                   areaWithType  bedRoom  bathroom balcony additionalRoom  \
# 0  Plot area 290(242.48 sq.m.)        5         4      3+   servant room
# 2       Plot area 61(51 sq.m.)       10        10      3+   servant room
# ...

# %%
df_cleaned = df.dropna(subset=['price','area','floorNum','facing','nearbyLocations','furnishDetails','features','rating','address'])
# Check the shape of the dataset after removing rows with nulls in specific columns
print(df_cleaned.shape)
# Out:
# (406, 20)

# %%
print(df_cleaned.isnull().sum())
# Out:
# property_name      0
# property_type      0
# society            0
# price              0
# price_per_sqft     0
# area               0
# areaWithType       0
# bedRoom            0
# bathroom           0
# balcony            0
# additionalRoom     0
# address            0
# floorNum           0
# facing             0
# agePossession      0
# nearbyLocations    0
# description        0
# furnishDetails     0
# features           0
# rating             0
# dtype: int64

# %%
df.columns
# Out:
# Index(['property_name', 'property_type', 'society', 'price', 'price_per_sqft',
#        'area', 'areaWithType', 'bedRoom', 'bathroom', 'balcony',
#        'additionalRoom', 'address', 'floorNum', 'facing', 'agePossession',
#        'nearbyLocations', 'description', 'furnishDetails', 'features',
#        'rating'],
#       dtype='object')

# %% [markdown]
# Data Visualisation

# %%
# Plot the distribution of house prices
plt.figure(figsize=(10, 6))
plt.hist(df['price'], bins=30, color='skyblue')
plt.title('Distribution of House Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %%
# Scatter plot of price vs area
plt.figure(figsize=(10, 6))
plt.scatter(df.head(10)['area'], df.head(10)['price'], alpha=0.5, color='orange')
plt.title('House Price vs Area')
plt.xlabel('Area')
plt.ylabel('Price')
plt.show()

# %%
plt.figure(figsize=(10, 6))
df.groupby('bedRoom')['price'].mean().plot(kind='bar', color='brown')
plt.title('Average House Price by Number of Bedrooms')
plt.xlabel('Number of Bedrooms')
plt.ylabel('Average Price')
plt.show()

# %%
#How does the number of bathrooms affect the price?
plt.figure(figsize=(10, 6))
df.groupby('bathroom')['price'].mean().plot(kind='bar', color='brown')
plt.title('Average House Price by Number of Bathrooms')
plt.xlabel('Number of Bathrooms')
plt.ylabel('Average Price')
plt.show()

# %%
# How does location affect house prices?
plt.figure(figsize=(10, 6))
df.groupby('address')['price'].mean().head(10).plot(kind='bar', color='blue')
plt.title('Average House Price by Location')
plt.xlabel('Address')
plt.ylabel('Average Price')
# Rotate the x-axis labels for better readability
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
#Does house age affect the price?
plt.figure(figsize=(10, 6))
plt.scatter(df.head(20)['agePossession'], df.head(20)['price'], alpha=0.5, color='red')
plt.title('House Price vs Age')
plt.xlabel('House Age')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# CONCLUSION:
# 1)house price depend on or based on its Area, Location, number of bathroom and bedroom.
# 2)According to the house age price may varry.
# 3)0000, greenwood city, gurgaon , haryana location have high price or rate of house.
